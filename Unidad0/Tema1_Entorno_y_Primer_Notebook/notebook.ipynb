# %% [markdown]
# # Tema 1: Entorno y primer notebook

# %% [markdown]
# ## Contexto
#
# En esta actividad se trabajará con notebooks, una herramienta que permite combinar texto, código y resultados en un mismo espacio.
#
# Este entorno será utilizado a lo largo de toda la asignatura para analizar datos y visualizar información.

# %% [markdown]
# ## Objetivo
#
# Al finalizar este notebook, se espera que el estudiante sea capaz de:
#
# - ejecutar celdas de código
# - reconocer la diferencia entre texto y código
# - interpretar resultados simples

# %% [markdown]
# ### Paso 1: Ejecutar una celda
#
# A continuación se muestra una instrucción simple. Ejecútala.

# %%
print("Hola, mundo")

# %% [markdown]
# **Pregunta:**
#
# ¿Qué ocurre al ejecutar la celda?

# %% [markdown]
# ### Paso 2: Realizar un cálculo simple
#
# Ejecuta la siguiente celda.

# %%
2 + 3

# %% [markdown]
# **Pregunta:**
#
# ¿Qué resultado se obtiene?

# %% [markdown]
# ### Paso 3: Modificar una instrucción
#
# Cambia los números en la siguiente celda y ejecútala nuevamente.

# %%
5 + 10

# %% [markdown]
# **Pregunta:**
#
# ¿Qué ocurre al cambiar los valores?

# %% [markdown]
# ### Paso 4: Variables
#
# Una variable permite guardar un valor.
#
# Ejecuta la siguiente celda.

# %%
numero = 7
numero

# %% [markdown]
# **Pregunta:**
#
# ¿Qué valor se muestra?

# %% [markdown]
# ### Paso 5: Operar con variables
#
# Ejecuta la siguiente celda.

# %%
numero * 2

# %% [markdown]
# **Pregunta:**
#
# ¿Qué resultado se obtiene?

# %% [markdown]
# ## Interpretación
#
# - Las celdas de código permiten ejecutar instrucciones.
# - Los resultados se muestran inmediatamente después de ejecutar la celda.
# - Es posible modificar valores y observar cómo cambian los resultados.

# %% [markdown]
# ## Cierre
#
# En este notebook se trabajó con:
#
# - ejecución de celdas
# - cálculos simples
# - uso de variables
#
# Estas herramientas serán utilizadas en las siguientes actividades para trabajar con datos.
